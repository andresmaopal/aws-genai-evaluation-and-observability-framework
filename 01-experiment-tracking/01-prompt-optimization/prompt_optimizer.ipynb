# %% [markdown]
# # 🎯 AI Prompt Optimization
#
# Transform your prompts into token-efficient, machine generated helpful instructions. This system combines the [4-D methodology](https://ai.gov.uk/knowledge-hub/prompts/prompt-optimiser/) with [Anthropic's best practices](https://www.anthropic.com/engineering/effective-context-engineering-for-ai-agents)
#
#
# ![image](images/prompt_helper.webp)
#
# ## Instructions
# 1. Run the setup cell below
# 2. Use the interactive widget to optimize your prompts
# 3. Select your preferred mode and target model from the dropdowns
# 4. Paste your prompt in the text area and click "Optimize Prompt"
#
# ## Prompt Optimizer

# %%
# !pip install ipywidgets "strands-agents==0.1.9" "strands-agents-tools==0.1.7" -q

# %%
from utils_lyra import LyraOptimizer, LyraChat

# Initialize Lyra and create chat interface
lyra = LyraOptimizer()
chat = LyraChat(lyra)
chat.display()
# Out:
# VBox(children=(HTML(value='<h4>💬 Lyra Prompt Optimizer</h4>'), HTML(value='<p><strong>Configure your optimization preferences:</strong></p>'), Dropdown(description='Mode:', layout=Layout(width='100%'), options=(('ADVANCED - Ask up to 5 questions to gather context, then optimize', 'ADVANCED'), ('EFFICIENT - Immediately optimize addressing core gaps', 'EFFICIENT')), value='EFFICIENT'), Dropdown(description='Target:', layout=Layout(width='100%'), options=(('Claude - Optimized for Anthropic Claude models', 'Claude'), ('General - Optimized for general LLM use', 'General')), value='Claude'), HTML(value='<p><strong>Enter your prompt to optimize:</strong></p>'), Textarea(layout=Layout(height='300px', width='100%'), placeholder='Paste your prompt here to optimize...'), HBox(children=(Button(button_style='primary', description='Optimize Prompt', layout=Layout(width='150px')), Button(button_style='warning', description='Clear', layout=Layout(width='100px')))), HTML(value='<hr>'), Output(layout=Layout(height='auto', max_height='none', overflow='visible', width='100%'))))
