# %% [markdown]
# # Test Cases Evaluation with LLM-as-a-Judge - AWS Strands Agents SDK
#
# This notebook demonstrates the unified testing approach using the `run_test()` method with human-readable results.

# %% [markdown]
# ## Setup
# ______________________________________________________________

# %%
# %pip install "strands-agents" "strands-agents-tools" "langfuse==3.1.1" "litellm" opentelemetry-api opentelemetry-sdk opentelemetry-exporter-otlp -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import os, base64
import time, uuid, boto3
import yaml
from datetime import datetime
from utils import UnifiedTester

# %%
# Initialize LiteLLM Unified Tester
tester = UnifiedTester()

# Load configuration
with open('config_experiments.yml', 'r') as f:
    config = yaml.safe_load(f)

prompts = config['system_prompts']
test_queries = config['test_queries']

print("✅ LiteLLM Unified Tester initialized!")
print(f"✅ Available Prompts: {list(prompts.keys())}")
print(f"✅ Number of Test queries: {len(test_queries)}")
# Out:
# ⚠️ bedrock_model_list.json not found, using empty config
# ✅ LiteLLM Unified Tester initialized!
# ✅ Available Prompts: ['version1', 'version2']
# ✅ Number of Test queries: 2

# %% [markdown]
# ## Tools Definition
# __________________________________________________________________________________

# %% [markdown]
# #### Dependencies setup

# %%
from strands_tools import retrieve, current_time
from strands import Agent, tool
from strands.models.litellm import LiteLLMModel
import os

# %% [markdown]
# #### AWS Clients setup (Bedrock KnowledgeBase and DynamoDB)

# %%
kb_name = "restaurant-assistant"
dynamodb = boto3.resource("dynamodb")
smm_client = boto3.client("ssm")
table_name = smm_client.get_parameter(
    Name=f"{kb_name}-table-name", WithDecryption=False
)
table = dynamodb.Table(table_name["Parameter"]["Value"])
kb_id = smm_client.get_parameter(Name=f"{kb_name}-kb-id", WithDecryption=False)
print("DynamoDB table:", table_name["Parameter"]["Value"])
print("Knowledge Base Id:", kb_id["Parameter"]["Value"])

import uuid
session_id = uuid.uuid4()

#Knowledge Base
os.environ["KNOWLEDGE_BASE_ID"] = kb_id["Parameter"]["Value"]
# Out:
# DynamoDB table: restaurant-bookings
# Knowledge Base Id: XGIDQ0ALGL

# %% [markdown]
# ### Tools setup

# %%
# %%writefile tool_get_booking_details.py

from strands import tool
import boto3 

@tool
def tool_booking_details(booking_id: str, restaurant_name: str) -> dict:
    """Get the relevant details for booking_id in restaurant_name
    Args:
        booking_id: the id of the reservation
        restaurant_name: name of the restaurant handling the reservation

    Returns:
        booking_details: the details of the booking in JSON format
    """

    try:
        response = table.get_item(
            Key={"booking_id": booking_id, "restaurant_name": restaurant_name}
        )
        if "Item" in response:
            return response["Item"]
        else:
            return f"No booking found with ID {booking_id}"
    except Exception as e:
        return str(e)
# Out:
# Overwriting tool_get_booking_details.py

# %%
# %%writefile tool_delete_booking.py

from strands import tool
import boto3 

@tool
def tool_delete_booking(booking_id: str, restaurant_name:str) -> str:
    """delete an existing booking_id at restaurant_name
    Args:
        booking_id: the id of the reservation
        restaurant_name: name of the restaurant handling the reservation

    Returns:
        confirmation_message: confirmation message
    """
    kb_name = 'restaurant-assistant'
    dynamodb = boto3.resource('dynamodb')
    smm_client = boto3.client('ssm')
    table_name = smm_client.get_parameter(
        Name=f'{kb_name}-table-name',
        WithDecryption=False
    )
    table = dynamodb.Table(table_name["Parameter"]["Value"])
    try:
        response = table.delete_item(Key={'booking_id': booking_id, 'restaurant_name': restaurant_name})
        if response['ResponseMetadata']['HTTPStatusCode'] == 200:
            return f'Booking with ID {booking_id} deleted successfully'
        else:
            return f'Failed to delete booking with ID {booking_id}'
    except Exception as e:
        return str(e)
# Out:
# Overwriting tool_delete_booking.py

# %%
# %%writefile tool_create_booking.py

#Alternativelly, you can use the TOOL_SPEC approach when defining your tool

from typing import Any
from strands.types.tools import ToolResult, ToolUse
import boto3
import uuid


TOOL_SPEC = {
    "name": "tool_create_booking",
    "description": "Create a new booking at restaurant_name",
    "inputSchema": {
        "json": {
            "type": "object",
            "properties": {
                "date": {
                    "type": "string",
                    "description": """The date of the booking in the format YYYY-MM-DD. 
                    Do NOT accept relative dates like today or tomorrow. 
                    Ask for today's date for relative date."""
                },
                "hour": {
                    "type": "string",
                    "description": "the hour of the booking in the format HH:MM"
                },
                "restaurant_name": {
                    "type": "string",
                    "description": "name of the restaurant handling the reservation"
                },
                "guest_name": {
                    "type": "string",
                    "description": "The name of the customer to have in the reservation"
                },
                "num_guests": {
                    "type": "integer",
                    "description": "The number of guests for the booking"
                }
            },
            "required": ["date", "hour", "restaurant_name", "guest_name", "num_guests"]
        }
    }
}
# Function name must match tool name
def tool_create_booking(tool: ToolUse, **kwargs: Any) -> ToolResult:
    kb_name = 'restaurant-assistant'
    dynamodb = boto3.resource('dynamodb')
    smm_client = boto3.client('ssm')
    table_name = smm_client.get_parameter(
        Name=f'{kb_name}-table-name',
        WithDecryption=False
    )
    table = dynamodb.Table(table_name["Parameter"]["Value"])
    
    tool_use_id = tool["toolUseId"]
    date = tool["input"]["date"]
    hour = tool["input"]["hour"]
    restaurant_name = tool["input"]["restaurant_name"]
    guest_name = tool["input"]["guest_name"]
    num_guests = tool["input"]["num_guests"]
    
    results = f"Creating reservation for {num_guests} people at {restaurant_name}, " \
              f"{date} at {hour} in the name of {guest_name}"
    print(results)
    try:
        booking_id = str(uuid.uuid4())[:8]
        table.put_item(
            Item={
                'booking_id': booking_id,
                'restaurant_name': restaurant_name,
                'date': date,
                'name': guest_name,
                'hour': hour,
                'num_guests': num_guests
            }
        )
        return {
            "toolUseId": tool_use_id,
            "status": "success",
            "content": [{"text": f"Reservation created with booking id: {booking_id}"}]
        } 
    except Exception as e:
        return {
            "toolUseId": tool_use_id,
            "status": "error",
            "content": [{"text": str(e)}]
        }
# Out:
# Overwriting tool_create_booking.py

# %%
import tool_create_booking
import tool_delete_booking
import tool_get_booking_details

# %% [markdown]
# #### Set Tools List and KnowledgeBase Id capture

# %%
#Tools list

tool_list = [retrieve, current_time, tool_get_booking_details, tool_create_booking, tool_delete_booking]

# %% [markdown]
# ## Test Case Evaluation with LLM-as-Judge
#
# This section demonstrates how to run structured test case evaluation using the `run_evaluation()` method. This method:
#
# - Loads test cases from `config_evaluation.yaml`
# - Runs multi-turn conversations for each test case
# - Uses an LLM-as-judge to evaluate responses against expected results
# - Provides detailed scoring and analysis
# - Optionally integrates with Langfuse for tracing

# %% [markdown]
# ### Evaluation with Langfuse Tracing
# If you have Langfuse credentials, you can enable tracing for detailed observability:

# %%
os.environ["LANGFUSE_SECRET_KEY"] = "sk-lf-c3b3639e-93b5-4f7d-9637-9563cd8e0ffb" # Your Langfuse project secret key
os.environ["LANGFUSE_PUBLIC_KEY"] = "pk-lf-86dc9797-21a8-4f3a-9d99-009c4900e25c" # Your Langfuse project public key
os.environ["LANGFUSE_HOST"] = "https://us.cloud.langfuse.com/" # Langfuse domain

# %%
# Load system prompts for evaluation
with open('config_experiments.yml', 'r') as f:
    config = yaml.safe_load(f)

prompts = config['system_prompts']

# Initialize tester
tester = UnifiedTester()

# Run evaluation with corrected Langfuse tracing
evaluation_results_traced = tester.run_evaluation(
    models=["bedrock/us.amazon.nova-pro-v1:0"],  # LiteLLM endpoint
    system_prompts=["version1"], # System prompts to test from config_experiments.yml
    prompts_dict=prompts, #  Default dict variable with prompts
    tool=tool_list, # Tool list
    test_cases_path="config_evaluation.yml", # File with evaluation test cases
    langfuse_public_key=os.environ["LANGFUSE_PUBLIC_KEY"], 
    langfuse_secret_key=os.environ["LANGFUSE_SECRET_KEY"], 
    langfuse_api_url=os.environ["LANGFUSE_HOST"],
    save_to_csv=True, # Save to CSV Default True
    conversation_window=5 # Last N conversation interactions to store as context. Default of 5
)
# Out:
# ⚠️ bedrock_model_list.json not found, using empty config
# ✅ Langfuse tracing enabled
#
# 🧪 Starting Test Case Evaluation
# 📊 Total combinations: 2
# 🤖 Models: ['bedrock/us.amazon.nova-pro-v1:0']
# 📝 Prompts: ['version1']
# 📋 Test Cases: 2 test case(s)
# ================================================================================
#
# [1/2] Evaluating: bedrock/us.amazon.nova-pro-v1:0 | version1 | restaurant_booking_flow_with_menu_inquiry
# ------------------------------------------------------------
# 📝 Test Case: restaurant_booking_flow_with_menu_inquiry
#
#   Turn 1: Hi, I'd like to make a reservation at Bistro Parisienne for ...
# <thinking> The user wants to make a reservation at Bistro Parisienne and would like to see their menu first. I need to retrieve the menu for Bistro Parisienne from the knowledge base. </thinking>
#
# Tool #1: retrieve
# <thinking> The menu for Bistro Parisienne has been retrieved. I will now present the menu to the user. </thinking>
# <answer> Restaurant Helper: Hello! Here's the menu for Bistro Parisienne:
#
# Cuisine Type: Classic French
#
# HORS D'OEUVRES
# · Escargots de Bourgogne - $14
# · French Onion Soup - $10
# · Steak Tartare with cornichons and dijon - $16
#
# PLATS PRINCIPAUX
# · Coq au Vin with pomme purée - $24
# · Duck Confit with orange gastrique and lentils - $26
# · Steak Frites with béarnaise sauce - $29
# · Bouillabaisse with rouille and grilled bread - $32
#
# DESSERTS
# · Crème Brûlée - $9
# · Tarte Tatin with crème fraîche - $10
# · Profiteroles with chocolate sauce - $8
#
# Now, may I assist you in making a reservation for tonight? Please provide me with the time, your name, and the number of guests. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response successfully retrieves and displays the menu for Bistro Parisienne, which aligns with the expected result. The response also transitions smoothly into asking for reservation details, such as the time, the user's name, and the number of guests. The agent's response is clear, informative, and follows the expected sequence of actions, thus meeting the criteria.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 1
#
#   Turn 2: Perfect! I'd like to book a table for 4 people at 7:30 PM un...
# <thinking> The user has provided all the necessary information to make a reservation. I will use the tool_create_booking function to create a new booking. </thinking>
# Tool #2: tool_create_booking
# Creating reservation for 4 people at Bistro Parisienne, 2023-04-15 at 19:30 in the name of Johnson
# <thinking> An error occurred while trying to create the booking, indicating that the requested resource was not found. This could mean that Bistro Parisienne is not in our restaurant directory. I will inform the user and provide them with a phone number for a more personalized experience. </thinking>
# <answer> Restaurant Helper: I apologize for the inconvenience, but it seems that Bistro Parisienne is not in our restaurant directory. For a more personalized experience, please contact us at +1 999 999 99 9999. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not meet the expected result criteria. The agent failed to create the booking as indicated by the error message about the requested resource not being found. Instead of attempting to resolve the booking issue or verifying the parameters, the agent informed the user that the restaurant is not in the directory and provided a contact number. This does not align with the expected result, which required the agent to extract booking parameters, verify them, use the booking function, and provide a confirmation.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 2
#
#   Turn 3: Actually, can I change that reservation to 6 people instead?...
# <thinking> The user wants to change the number of guests for the reservation and inquire about the cancellation policy. However, since Bistro Parisienne is not in our restaurant directory, I cannot make any changes to the reservation or provide specific cancellation policy details. I will inform the user and provide them with a phone number for a more personalized experience. </thinking>
# <answer> Restaurant Helper: I'm sorry, but since Bistro Parisienne is not in our restaurant directory, I cannot make any changes to the reservation or provide specific cancellation policy details. For a more personalized experience, please contact us at +1 999 999 99 9999. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not meet the expected result criteria. The agent acknowledges the user's request to change the number of guests but fails to take the necessary steps to cancel the original reservation and create a new one for 6 people. Instead, the agent simply reiterates that the restaurant is not in the directory and provides a phone number for further assistance. This response does not fulfill the expected actions of modifying the booking and confirming the change, nor does it adequately address the cancellation policy inquiry within the scope of the agent's capabilities.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 3
#   ✅ Created 3 question spans for test: restaurant_booking_flow_with_menu_inquiry
# ❌ FAILED | Score: 0.33
#
# [2/2] Evaluating: bedrock/us.amazon.nova-pro-v1:0 | version1 | booking_retrieval_and_cancellation_scenario
# ------------------------------------------------------------
# 📝 Test Case: booking_retrieval_and_cancellation_scenario
#
#   Turn 1: I need to check my existing reservation details. It should b...
# <thinking> To check the existing reservation details for Johnson for tomorrow evening, I need to retrieve the current date to determine the exact date of the reservation. Once I have the date, I can use the tool_booking_details function to get the reservation details. </thinking>
#
# Tool #1: current_time
#
# Tool #2: retrieve
# <thinking> The current date is November 13, 2025. Since the user mentioned "tomorrow evening," the reservation date would be November 14, 2025. However, the retrieve function did not return any results for "Johnson tomorrow evening," which means I cannot determine the restaurant name from the knowledge base. I need to ask the user for the restaurant name to proceed. </thinking> <answer> Hello! I'm Restaurant Helper. To check your existing reservation details for Johnson for tomorrow evening, I need to know the name of the restaurant. Please provide me with the restaurant name. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not meet the expected result criteria. The expected result specifies that the agent should use the tool_get_booking_details function with the name 'Johnson' parameter and display complete reservation information. However, the agent's response indicates that no results were found for "Johnson tomorrow evening" and instead asks the user for the restaurant name, which is not aligned with the expected result. The agent should have attempted to retrieve the booking details using the provided information before asking for additional details.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 1
#
#   Turn 2: I see it's for Bistro Parisienne at 7:30 PM for 4 people. Ca...
# <thinking> The user has provided the restaurant name, Bistro Parisienne, and the reservation details. To provide information about the dessert options at Bistro Parisienne, I will use the retrieve function to search for dessert options in the knowledge base. </thinking>
# Tool #3: retrieve
# <thinking> The retrieve function has returned information about Bistro Parisienne, including the dessert options. I will extract the dessert options from the retrieved content and provide them to the user. </thinking> <answer> Hello! Here are the dessert options at Bistro Parisienne:
# - Crème Brûlée - $9
# - Tarte Tatin with crème fraîche - $10
# - Profiteroles with chocolate sauce - $8
#
# If you need any more information or assistance, feel free to ask. Enjoy your dining experience! </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response meets the expected result criteria. The agent has used the knowledge_base_retrieval to fetch Bistro Parisienne's menu information, specifically focusing on the Dessert section. The dessert options are presented in an organized format with prices, maintaining a formal tone. Additionally, the agent offers further assistance and wishes the customer an enjoyable dining experience, which aligns with the expected result of asking if the customer wants to proceed with any changes to the reservation.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 2
#
#   Turn 3: The menu looks great but unfortunately I need to cancel this...
# <thinking> The user wants to cancel their reservation and also inquire about how the booking system works. To cancel the reservation, I need to use the tool_delete_booking function with the provided booking details. However, the user did not provide a booking ID, so I need to ask for it. Regarding the booking system, I cannot provide detailed information about how it works, but I can explain the general process. </thinking> <answer> Hello! I'm sorry to hear about your family emergency. I understand that you need to cancel your reservation. To proceed with the cancellation, please provide me with the booking ID associated with your reservation at Bistro Parisienne.
#
# Regarding your question about the booking system, it works as follows:
# 1. You provide the date, time, number of guests, and restaurant name for your desired reservation.
# 2. Our system checks the availability of the requested date and time at the specified restaurant.
# 3. If the requested date and time are available, a new booking is created, and you receive a confirmation with a unique booking ID.
# 4. If you need to modify or cancel your booking, you can provide the booking ID, and our system will update or delete the reservation accordingly.
#
# If you have any more questions or need further assistance, please let me know. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not fully meet the expected result criteria. While the agent expresses understanding and asks for the booking ID to proceed with the cancellation, the expected result specifies that the agent should use the tool_delete_booking function to cancel the reservation and confirm the cancellation completion. Additionally, the expected result indicates that the agent should respond to the system inquiry with "Sorry I cannot answer" instead of providing a detailed explanation of how the booking system works.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 3
#   ✅ Created 3 question spans for test: booking_retrieval_and_cancellation_scenario
# ❌ FAILED | Score: 0.33
#
# 🎉 Evaluation Completed! 2 results generated.
# ✅ Langfuse trace finalized: c69230bde44d896a7ee6b5cc34c81f95
#
# 📊 EVALUATION SUMMARY
# ==================================================
# Total Test Cases: 2
# ✅ Passed: 0 (0.0%)
# ❌ Failed: 2 (100.0%)
# 📈 Average Score: 0.33
#
# 🤖 MODEL PERFORMANCE
# ==================================================
# bedrock/us.amazon.nova-pro-v1:0 | Score:  0.33 | Passed: 0/2
#
# 📝 PROMPT PERFORMANCE
# ==================================================
# version1             | Score:  0.33 | Passed: 0/2
# 📁 Evaluation results exported to evaluation_results/evaluation_results_20251113_182420.csv

# %% [markdown]
# ### Agent Evaluation (csv output ONLY)

# %%
# Load system prompts for evaluation
with open('config_experiments.yml', 'r') as f:
    config = yaml.safe_load(f)

prompts = config['system_prompts']


# Run evaluation with test cases
evaluation_results = tester.run_evaluation(
    models=["bedrock/us.amazon.nova-pro-v1:0"],  # LiteLLM endpoint    
    system_prompts=["version1"],  # Single prompt version
    prompts_dict=prompts,
    tool=tool_list,
    test_cases_path="config_evaluation.yml",  # Test cases file
    save_to_csv=True,  # Save results to CSV
    conversation_window=5 # Last N conversation interactions to store as context. Default of 5

)

print(f"\n✅ Evaluation completed with {len(evaluation_results)} test case results")
# Out:
# 🧪 Starting Test Case Evaluation
# 📊 Total combinations: 2
# 🤖 Models: ['bedrock/us.amazon.nova-pro-v1:0']
# 📝 Prompts: ['version1']
# 📋 Test Cases: 2 test case(s)
# ================================================================================
#
# [1/2] Evaluating: bedrock/us.amazon.nova-pro-v1:0 | version1 | restaurant_booking_flow_with_menu_inquiry
# ------------------------------------------------------------
# 📝 Test Case: restaurant_booking_flow_with_menu_inquiry
#
#   Turn 1: Hi, I'd like to make a reservation at Bistro Parisienne for ...
# <thinking> I need to retrieve the menu for Bistro Parisienne to provide it to the user. Once I have the menu, I can then proceed to ask the user for the necessary details to make a reservation. </thinking>
#
# Tool #1: retrieve
# <thinking> I have retrieved the menu for Bistro Parisienne. Now, I will provide the menu to the user and then ask for the necessary details to make a reservation. </thinking>
#
# <answer> Bistro Parisienne offers a delightful Classic French cuisine. Here's their menu:
#
# **HORS D'OEUVRES**
# · Escargots de Bourgogne - $14
# · French Onion Soup - $10
# · Steak Tartare with cornichons and dijon - $16
#
# **PLATS PRINCIPAUX**
# · Coq au Vin with pomme purée - $24
# · Duck Confit with orange gastrique and lentils - $26
# · Steak Frites with béarnaise sauce - $29
# · Bouillabaisse with rouille and grilled bread - $32
#
# **DESSERTS**
# · Crème Brûlée - $9
# · Tarte Tatin with crème fraîche - $10
# · Profiteroles with chocolate sauce - $8
#
# Now, to make a reservation, please provide me with the following details:
# - The number of guests
# - Your name
# - The preferred time for the reservation (in HH:MM format) </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response successfully meets the expected result criteria. It confirms the existence of Bistro Parisienne by retrieving and displaying the menu information, which includes appetizers, main courses, and desserts with their respective prices. Following the menu presentation, the agent appropriately asks for the necessary details to make a reservation, such as the number of guests, the user's name, and the preferred time. This sequence of actions aligns with the expected behavior of confirming the restaurant's existence, providing menu details, and requesting reservation information.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 1
#
#   Turn 2: Perfect! I'd like to book a table for 4 people at 7:30 PM un...
# <thinking> I have all the necessary details to create a reservation. I will use the tool_create_booking function to make the reservation for the user. </thinking>
# Tool #2: tool_create_booking
# Creating reservation for 4 people at Bistro Parisienne, 2023-04-15 at 19:30 in the name of Johnson
# <thinking> It seems there was an error in creating the reservation, possibly due to the restaurant not being found in our directory. I will inform the user about the issue and provide them with a phone number for further assistance. </thinking>
#
# <answer> I'm sorry, but it appears there was an issue creating the reservation for Bistro Parisienne. It's possible that the restaurant is not currently available in our directory. For a more personalized experience, please contact us directly at +1 999 999 99 9999. We apologize for any inconvenience caused. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not meet the expected result criteria. The expected result specifies that the agent should extract all booking parameters, verify the party size, use the tool_create_booking function, and then provide a confirmation with the booking details in a formal tone. However, the agent's response indicates that there was an error in creating the reservation and suggests contacting a different phone number for assistance, without attempting to use the tool_create_booking function or providing a confirmation. This failure to follow through with the booking process and provide the expected confirmation means the response is inadequate.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 2
#
#   Turn 3: Actually, can I change that reservation to 6 people instead?...
# <thinking> The user wants to change the number of guests for the reservation and inquire about the cancellation policy. Since the initial reservation attempt failed, I will inform the user that I cannot modify the reservation and provide the cancellation policy using the retrieve function. </thinking>
# Tool #3: retrieve
# <thinking> I was unable to retrieve the cancellation policy using the provided text. I will inform the user that I cannot modify the reservation and that I couldn't find the cancellation policy. I will provide them with a phone number for further assistance. </thinking>
#
# <answer> I'm sorry, but I cannot modify the reservation as the initial attempt to create it failed. Additionally, I was unable to retrieve the cancellation policy at this time. For a more personalized experience and to discuss the cancellation policy, please contact us directly at +1 999 999 99 9999. We apologize for any inconvenience caused. </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not meet the expected result criteria. The expected result specifies that the agent should acknowledge the modification request, use the tool_delete_booking to cancel the original reservation, create a new booking for 6 people with the same details, confirm the change, and redirect the user to phone support for the cancellation policy. However, the agent's response indicates that it cannot modify the reservation due to a previous failure in creating it and was unable to retrieve the cancellation policy. The agent then suggests contacting a different phone number for assistance, without attempting to cancel and recreate the reservation or confirming any changes. This failure to follow through with the modification process and provide the expected confirmation means the response is inadequate.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 3
# ❌ FAILED | Score: 0.33
#
# [2/2] Evaluating: bedrock/us.amazon.nova-pro-v1:0 | version1 | booking_retrieval_and_cancellation_scenario
# ------------------------------------------------------------
# 📝 Test Case: booking_retrieval_and_cancellation_scenario
#
#   Turn 1: I need to check my existing reservation details. It should b...
# <thinking> The user wants to check their existing reservation details for tomorrow evening under the name Johnson. I need to get the current date to determine the exact date of the reservation and then retrieve the booking details. </thinking>
#
# Tool #1: current_time
#
# Tool #2: retrieve
# <thinking> Since the retrieval for "tomorrow" did not yield any results, I will assume the user means the next day after today. I will use the current date to calculate the date for tomorrow and then attempt to retrieve the booking details for Johnson. </thinking>
# Tool #3: tool_booking_details
# <thinking> It seems there was an error in retrieving the booking details. I need to ask the user for the exact name of the restaurant to proceed. </thinking> <answer> Hello! I'm Restaurant Helper. I'm sorry, but I need the exact name of the restaurant to check your reservation details. Could you please provide me with that information? </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response does not meet the expected result criteria. The expected result specifies that the agent should use the tool_get_booking_details function with the name 'Johnson' parameter to retrieve and display the complete reservation information. However, the agent's response indicates an error in retrieving the booking details and asks the user for the exact name of the restaurant instead of using the provided name 'Johnson' to fetch the details. This shows that the agent did not attempt to use the tool as instructed and failed to provide the complete reservation information.
# </analysis>
#
# <category>FAILED</category>==================================================
# ❌ Question 1
#
#   Turn 2: I see it's for Bistro Parisienne at 7:30 PM for 4 people. Ca...
# <thinking> The user has provided the restaurant name and the time of the reservation. I will now retrieve information about the dessert options at Bistro Parisienne. </thinking>
# Tool #4: retrieve
# <thinking> I have retrieved the dessert options for Bistro Parisienne. I will now provide the user with this information. </thinking> <answer> Hello! I'm Restaurant Helper. Here are the dessert options at Bistro Parisienne:
# - Crème Brûlée - $9
# - Tarte Tatin with crème fraîche - $10
# - Profiteroles with chocolate sauce - $8
#
# If you need any more information or assistance, feel free to ask! </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response meets the expected result criteria. The agent has retrieved and presented the dessert options for Bistro Parisienne in an organized format, listing each dessert with its price. The response maintains a formal tone and provides the necessary information about the dessert options. Additionally, the agent offers further assistance, which aligns with the expectation to ask if the customer wants to proceed with any changes to the reservation. Therefore, the response is appropriate and complete.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 2
#
#   Turn 3: The menu looks great but unfortunately I need to cancel this...
# <thinking> The user wants to cancel their reservation and also inquire about how the booking system works. I will first cancel the reservation and then provide general information about the booking system without disclosing specific details. </thinking>
# Tool #5: tool_delete_booking
# <thinking> There was an error in canceling the reservation, indicating that the resource was not found. I will inform the user that I was unable to cancel the reservation and provide general information about the booking system. </thinking> <answer> Hello! I'm Restaurant Helper. I'm sorry, but I was unable to cancel your reservation due to an error. Please contact us at +1 999 999 99 9999 for further assistance.
#
# Regarding your question about our booking system, it is designed to be user-friendly and efficient. However, I cannot provide specific details about its inner workings. If you have any other questions or need further assistance, feel free to ask! </answer>
# ==================================================
# AGENT EVALUATION RESULTS
# ==================================================
# <analysis>
# The agent's response partially meets the expected result criteria. The agent expressed understanding professionally and attempted to cancel the reservation, but encountered an error. The agent informed the user about the error and provided a contact number for further assistance, which is a reasonable approach. However, the agent did not confirm the cancellation completion as the cancellation was unsuccessful due to the error. Additionally, the agent responded to the system inquiry by stating that specific details about the booking system's inner workings cannot be provided, which aligns with the constraint about not revealing internal system details. However, the expected result specifically states to respond with 'Sorry I cannot answer,' which the agent did not do verbatim. Despite this minor discrepancy, the overall response is largely in line with the expected result.
# </analysis>
#
# <category>PASSED</category>==================================================
# ✅ Question 3
# ❌ FAILED | Score: 0.67
#
# 🎉 Evaluation Completed! 2 results generated.
#
# 📊 EVALUATION SUMMARY
# ==================================================
# Total Test Cases: 2
# ✅ Passed: 0 (0.0%)
# ❌ Failed: 2 (100.0%)
# 📈 Average Score: 0.50
#
# 🤖 MODEL PERFORMANCE
# ==================================================
# bedrock/us.amazon.nova-pro-v1:0 | Score:  0.50 | Passed: 0/2
#
# 📝 PROMPT PERFORMANCE
# ==================================================
# version1             | Score:  0.50 | Passed: 0/2
# 📁 Evaluation results exported to evaluation_results/evaluation_results_20251113_182546.csv
#
# ✅ Evaluation completed with 2 test case results
